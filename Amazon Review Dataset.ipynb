# %%
import pandas as pd
import umap
from sentence_transformers import SentenceTransformer, util
import torch
import hdbscan
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import cosine
from sklearn.model_selection import train_test_split
import time
# %matplotlib inline

# %%
# df_text = pd.read_csv('cleaned_data.csv', usecols=['cleaned_description','lemmatized_description'], converters={'lemmatized_description': eval})
df_text = pd.read_csv('cleaned_reviews2.csv', usecols=['text','summary'])
df_text.head(5)
# Out:
#                                                 text  \
# 0  saltwater taffy great flavors soft chewy candy...
# 1  know cactus tequila unique combination ingredi...
# 2  one boys needed lose weight put food floor chu...
# 3  cats happily eating felidae platinum two years...
# 4  daughter loves twizzlers shipment six pounds r...
#
#                                              summary
# 0         great just as good as the expensive brands
# 1                    the best hot sauce in the world
# 2  my cats love this diet food better than their ...
# 3               my cats are not fans of the new food
# 4             lots of twizzlers just what you expect

# %%
# get summary above word len 7

# %%
summary = df_text['summary'].to_list()

corpus, queries = train_test_split(summary, train_size=5000, test_size=50)
print(f"Train:{len(summary_train)} Validate: {len(summary_validate)}")
# Out:
# Train:5000 Validate: 50

# %%
def similarity(query_embeddings,docs_embeddings,max_n=10, top_k=5):
    cos_scores = util.pytorch_cos_sim(query_embeddings, docs_embeddings)[0]
    cos_scores = cos_scores.cpu()
    top_results = torch.topk(cos_scores, k=max_n)
    return zip(top_results[0], top_results[1])

# %%
def get_query_top_k(query, query_embeddings, docs, docs_embeddings, max_n=10, top_k=5, min_p=0.7, exact_match=True):
    count=0
    top_k_list = []
    for score, idx in similarity(query_embeddings, docs_embeddings, max_n=max_n, top_k=top_k):
        score = score.item()
        if count<top_k and ((score>min_p and exact_match) or (score<=0.99 and score>min_p)): # we skip exact match if so required, because of floating point precision we set exact match to 0.99
            count=count+1
            top_k_list.append({"query":query,"sentence":docs[idx],"score":score})
    return top_k_list

# %%
model = SentenceTransformer('distilbert-base-nli-stsb-mean-tokens')

# %%
embeddings = model.encode(summary, convert_to_tensor=True, show_progress_bar=True)

# %%
def sent_similarity(corpus, queries, threshold=0.8, exact_match=True):
    start = time.time()
    embedder = SentenceTransformer('distilbert-base-nli-stsb-mean-tokens')

    corpus_embeddings = embedder.encode(corpus, convert_to_tensor=True)
    
    # Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
    n = 10
    top_k = 5
    
    data = []
    for query in queries:
        query_embeddings = embedder.encode(query, convert_to_tensor=True)
        top_k_list = get_query_top_k(query, query_embeddings, corpus, corpus_embeddings, max_n = n, top_k = top_k, min_p=threshold, exact_match=exact_match)
        data.extend(top_k_list)
    
    df = pd.DataFrame(data)
#     df.to_csv(output_file,index=False,sep="\t")
    end = time.time()
    ex_time = int(end - start)
    print(f'execution time {ex_time}')
    return df

# %%
df = sent_similarity(corpus, queries, 0.8, True)
df
# Out:
# execution time 7
#                                     query  \
# 0                    as good as in europe
# 1                    as good as in europe
# 2           helpful but not quite miracle
# 3           helpful but not quite miracle
# 4           helpful but not quite miracle
# 5           helpful but not quite miracle
# 6           helpful but not quite miracle
# 7            great bargain on great candy
# 8            great bargain on great candy
# 9            great bargain on great candy
# 10             my cats would not touch it
# 11             my cats would not touch it
# 12             my cats would not touch it
# 13             my cats would not touch it
# 14             my cats would not touch it
# 15    great tasting gluten free spaghetti
# 16    great tasting gluten free spaghetti
# 17    great tasting gluten free spaghetti
# 18              this is really good stuff
# 19              this is really good stuff
# 20              this is really good stuff
# 21              this is really good stuff
# 22              this is really good stuff
# 23              great value for the money
# 24              great value for the money
# 25              great value for the money
# 26              great value for the money
# 27            my dogs love these the best
# 28            my dogs love these the best
# 29            my dogs love these the best
# 30            my dogs love these the best
# 31            my dogs love these the best
# 32                the best dog treat ever
# 33                the best dog treat ever
# 34                the best dog treat ever
# 35                the best dog treat ever
# 36                the best dog treat ever
# 37  do not think you will find any better
# 38  do not think you will find any better
# 39  do not think you will find any better
# 40                 not as bad as expected
# 41                 not as bad as expected
# 42                 not as bad as expected
# 43                 not as bad as expected
# 44                 not as bad as expected
#
#                                              sentence     score
# 0              as good as the best have had in europe  0.912450
# 1                 this is amazing product from europe  0.850032
# 2                         pretty good but not amazing  0.851143
# 3                             nice but not very tasty  0.834629
# 4                            very good but not enough  0.830070
# 5                         delicious but not good gift  0.828679
# 6                              good but not that good  0.814119
# 7                           damn good candy if say so  0.867343
# 8                       great candy and great service  0.854182
# 9                          one of the best candy ever  0.833833
# 10                        my cats will not touch this  0.942686
# 11                             cat would not touch it  0.898872
# 12                            my cats will not eat it  0.882110
# 13                               cat will not go near  0.879054
# 14                         my cats will not eat these  0.841923
# 15                        best gluten free pasta ever  0.830776
# 16                    awesome gluten free penne pasta  0.814659
# 17                        very good gluten free pasta  0.810700
# 18                          this stuff is really good  0.962684
# 19                             so so so so so so good  0.901936
# 20                        this turned out to be great  0.901846
# 21                                 as good as it gets  0.876347
# 22                                 as good as it gets  0.876347
# 23              excellent quality and value for money  0.913502
# 24                         good product for the money  0.847989
# 25                         good product for the money  0.847989
# 26                           good value for its price  0.815464
# 27                          my dogs love these things  0.969036
# 28                      my dogs absolutely love these  0.948648
# 29                            my dogs love this stuff  0.940029
# 30                          my dogs love love love it  0.938348
# 31                     my dog likes these best of all  0.931689
# 32                            the best dog treat ever  1.000000
# 33                   best healthy dog treat out there  0.862124
# 34                          awesome treat for my dogs  0.823488
# 35                           great treat for your dog  0.819247
# 36                          my dog loves these treats  0.817385
# 37                     have not found anything better  0.829209
# 38                         it does not get any better  0.823275
# 39               it does not get any better then this  0.820365
# 40                            not as good as expected  0.872694
# 41                            not as good as expected  0.872694
# 42  not to bad but not as good as you might think ...  0.824807
# 43                         not as pleased as expected  0.823787
# 44                  not half bad pretty good actually  0.815234
